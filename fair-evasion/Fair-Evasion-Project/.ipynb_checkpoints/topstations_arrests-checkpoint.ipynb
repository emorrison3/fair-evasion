# %%
library(dplyr)
library(readr)
stations_arrests <- read_csv("clean arrests.csv") #read in arrest data 
station_local_demo <- read_csv("local_station_demo.csv") #read in neighborhood demographic data
station_local_demo <- subset(station_local_demo, select=c(AI, API, Black, Hispanic, Unknown, White)) #drop 'Total' column
# Out:
# Attaching package: ‘dplyr’
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
# Parsed with column specification:
# cols(
#   AI = col_double(),
#   API = col_double(),
#   Black = col_double(),
#   Hispanic = col_double(),
#   Unknown = col_double(),
#   White = col_double(),
#   Total = col_double()
# )
# Parsed with column specification:
# cols(
#   Hispanic = col_double(),
#   White = col_double(),
#   Black = col_double(),
#   AI = col_double(),
#   API = col_double(),
#   Unknown = col_double()
# )

# %%
summons_matrix <- data.matrix(stations_arrests, rownames.force = NA)
demo_matrix <- data.matrix(station_local_demo, rownames.force = NA) #turn dfs into matrices to perform operations

# %%
b_test <- function(x, n, p){   ##perform binomial test on the number of summons given to a specific group (x) out of the total number of summons 
    ##for that sation (n) comparing it to that group's representation in the local area (p)
  
    binom.test(x, n, p)
    } 

print(mapply(b_test, summons_matrix[,1:6], summons_matrix[,7], demo_matrix[,1:6])) 
##allows rowwise application of b_test function
# Out:
#             [,1]                  [,2]                  [,3]
# statistic   0                     0                     0
# parameter   27                    17                    17
# p.value     TRUE                  1                     1
# conf.int    Numeric,2             Numeric,2             Numeric,2
# estimate    0                     0                     0
# null.value  0                     0.0024818             0.000738861
# alternative "two.sided"           "two.sided"           "two.sided"
# method      "Exact binomial test" "Exact binomial test" "Exact binomial test"
# data.name   "x and n"             "x and n"             "x and n"
#             [,4]                  [,5]                  [,6]
# statistic   0                     0                     0
# parameter   17                    16                    11
# p.value     1                     TRUE                  1
# conf.int    Numeric,2             Numeric,2             Numeric,2
# estimate    0                     0                     0
# null.value  0.00346597            0                     0.00544259
# alternative "two.sided"           "two.sided"           "two.sided"
# method      "Exact binomial test" "Exact binomial test" "Exact binomial test"
# data.name   "x and n"             "x and n"             "x and n"
#             [,7]                  [,8]                  [,9]
# statistic   0                     0                     0
# parameter   11                    11                    11
# p.value     TRUE                  1                     1
# conf.int    Numeric,2             Numeric,2             Numeric,2
# estimate    0                     0                     0
# null.value  0                     0.001493811           0.004285517
# alternative "two.sided"           "two.sided"           "two.sided"
# method      "Exact binomial test" "Exact binomial test" "Exact binomial test"
# data.name   "x and n"             "x and n"             "x and n"
#             [,10]                 [,11]                 [,12]
# statistic   0                     0                     0
# parameter   10                    27                    17
# p.value     1                     0.06867334            1
# conf.int    Numeric,2             Numeric,2             Numeric,2
# estimate    0                     0                     0
# null.value  0.000975783           0.1213858             0.006535407
# alternative "two.sided"           "two.sided"           "two.sided"
# method      "Exact binomial test" "Exact binomial test" "Exact binomial test"
# data.name   "x and n"             "x and n"             "x and n"
#             [,13]                 [,14]                 [,15]
# statistic   0                     0                     1
# parameter   17                    17                    16
# p.value     0.6209416             1                     1
# conf.int    Numeric,2             Numeric,2             Numeric,2
# estimate    0                     0                     0.0625
# null.value  0.05814514            0.0342996             0.07817426
# alternative "two.sided"           "two.sided"           "two.sided"
# method      "Exact binomial test" "Exact binomial test" "Exact binomial test"
# data.name   "x and n"             "x and n"             "x and n"
#             [,16]                 [,17]                 [,18]
# statistic   0                     0                     1
# parameter   11                    11                    11
# p.value     1                     0.3794733             1
# conf.int    Numeric,2             Numeric,2             Numeric,2
# estimate    0                     0                     0.09090909
# null.value  0.0055531             0.1273951             0.1320956
# alternative "two.sided"           "two.sided"           "two.sided"
# method      "Exact binomial test" "Exact binomial test" "Exact binomial test"
# data.name   "x and n"             "x and n"             "x and n"
#             [,19]                 [,20]                 [,21]
# statistic   1                     0                     22
# parameter   11                    10                    27
# p.value     1                     1                     7.748523e-14
# conf.int    Numeric,2             Numeric,2             Numeric,2
# estimate    0.09090909            0                     0.8148148
# null.value  0.1066771             0.003326532           0.1574368
# alternative "two.sided"           "two.sided"           "two.sided"
# method      "Exact binomial test" "Exact binomial test" "Exact binomial test"
# data.name   "x and n"             "x and n"             "x and n"
#             [,22]                 [,23]                 [,24]
# statistic   14                    12                    12
# parameter   17                    17                    17
# p.value     1                     0.08635958            0.6197232
# conf.int    Numeric,2             Numeric,2             Numeric,2
# estimate    0.8235294             0.7058824             0.7058824
# null.value  0.8282181             0.4751518             0.6122614
# alternative "two.sided"           "two.sided"           "two.sided"
# method      "Exact binomial test" "Exact binomial test" "Exact binomial test"
# data.name   "x and n"             "x and n"             "x and n"
#             [,25]                 [,26]                 [,27]
# statistic   13                    8                     7
# parameter   16                    11                    11
# p.value     1.326126e-07          0.001559858           0.001577608
# conf.int    Numeric,2             Numeric,2             Numeric,2
# estimate    0.8125                0.7272727             0.6363636
# null.value  0.1901129             0.2597248             0.1930125
# alternative "two.sided"           "two.sided"           "two.sided"
# method      "Exact binomial test" "Exact binomial test" "Exact binomial test"
# data.name   "x and n"             "x and n"             "x and n"
#             [,28]                 [,29]                 [,30]
# statistic   2                     5                     6
# parameter   11                    11                    10
# p.value     0.1527995             0.169527              0.01692776
# conf.int    Numeric,2             Numeric,2             Numeric,2
# estimate    0.1818182             0.4545455             0.6
# null.value  0.06380708            0.2614626             0.2423933
# alternative "two.sided"           "two.sided"           "two.sided"
# method      "Exact binomial test" "Exact binomial test" "Exact binomial test"
# data.name   "x and n"             "x and n"             "x and n"
#             [,31]                 [,32]                 [,33]
# statistic   4                     2                     5
# parameter   27                    17                    17
# p.value     0.7725111             1                     1
# conf.int    Numeric,2             Numeric,2             Numeric,2
# estimate    0.1481481             0.1176471             0.2941176
# null.value  0.1297213             0.1283091             0.319734
# alternative "two.sided"           "two.sided"           "two.sided"
# method      "Exact binomial test" "Exact binomial test" "Exact binomial test"
# data.name   "x and n"             "x and n"             "x and n"
#             [,34]                 [,35]                 [,36]
# statistic   2                     1                     3
# parameter   17                    16                    11
# p.value     0.6549919             0.2233357             0.004151107
# conf.int    Numeric,2             Numeric,2             Numeric,2
# estimate    0.1176471             0.0625                0.2727273
# null.value  0.08687433            0.2220953             0.7014311
# alternative "two.sided"           "two.sided"           "two.sided"
# method      "Exact binomial test" "Exact binomial test" "Exact binomial test"
# data.name   "x and n"             "x and n"             "x and n"
#             [,37]                 [,38]                 [,39]
# statistic   3                     5                     3
# parameter   11                    11                    11
# p.value     0.4571817             0.1936726             1
# conf.int    Numeric,2             Numeric,2             Numeric,2
# estimate    0.2727273             0.4545455             0.2727273
# null.value  0.1946092             0.6742958             0.2817382
# alternative "two.sided"           "two.sided"           "two.sided"
# method      "Exact binomial test" "Exact binomial test" "Exact binomial test"
# data.name   "x and n"             "x and n"             "x and n"
#             [,40]                 [,41]                 [,42]
# statistic   2                     0                     0
# parameter   10                    27                    17
# p.value     0.001324266           0.399945              1
# conf.int    Numeric,2             Numeric,2             Numeric,2
# estimate    0.2                   0                     0
# null.value  0.7074426             0.05261787            0.02026803
# alternative "two.sided"           "two.sided"           "two.sided"
# method      "Exact binomial test" "Exact binomial test" "Exact binomial test"
# data.name   "x and n"             "x and n"             "x and n"
#             [,43]                 [,44]                 [,45]
# statistic   0                     0                     0
# parameter   17                    17                    16
# p.value     1                     1                     1
# conf.int    Numeric,2             Numeric,2             Numeric,2
# estimate    0                     0                     0
# null.value  0.02679174            0.0324991             0.02837301
# alternative "two.sided"           "two.sided"           "two.sided"
# method      "Exact binomial test" "Exact binomial test" "Exact binomial test"
# data.name   "x and n"             "x and n"             "x and n"
#             [,46]                 [,47]                 [,48]
# statistic   0                     0                     0
# parameter   11                    11                    11
# p.value     1                     1                     1
# conf.int    Numeric,2             Numeric,2             Numeric,2
# estimate    0                     0                     0
# null.value  0.007100232           0.04006995            0.004481434
# alternative "two.sided"           "two.sided"           "two.sided"
# method      "Exact binomial test" "Exact binomial test" "Exact binomial test"
# data.name   "x and n"             "x and n"             "x and n"
#             [,49]                 [,50]                 [,51]
# statistic   0                     0                     1
# parameter   11                    10                    27
# p.value     1                     1                     2.7325e-08
# conf.int    Numeric,2             Numeric,2             Numeric,2
# estimate    0                     0                     0.03703704
# null.value  0.0177872             0.006741772           0.5388382
# alternative "two.sided"           "two.sided"           "two.sided"
# method      "Exact binomial test" "Exact binomial test" "Exact binomial test"
# data.name   "x and n"             "x and n"             "x and n"
#             [,52]                 [,53]                 [,54]
# statistic   1                     0                     3
# parameter   17                    17                    17
# p.value     0.2156633             0.2515616             0.7771604
# conf.int    Numeric,2             Numeric,2             Numeric,2
# estimate    0.05882353            0                     0.1764706
# null.value  0.01418762            0.1194385             0.2305996
# alternative "two.sided"           "two.sided"           "two.sided"
# method      "Exact binomial test" "Exact binomial test" "Exact binomial test"
# data.name   "x and n"             "x and n"             "x and n"
#             [,55]                 [,56]                 [,57]
# statistic   1                     0                     1
# parameter   16                    11                    11
# p.value     0.0005867786          1                     0.0287004
# conf.int    Numeric,2             Numeric,2             Numeric,2
# estimate    0.0625                0                     0.09090909
# null.value  0.4812446             0.02074815            0.4449133
# alternative "two.sided"           "two.sided"           "two.sided"
# method      "Exact binomial test" "Exact binomial test" "Exact binomial test"
# data.name   "x and n"             "x and n"             "x and n"
#             [,58]                 [,59]                 [,60]
# statistic   3                     2                     2
# parameter   11                    11                    10
# p.value     0.1465955             0.5215051             0.05588532
# conf.int    Numeric,2             Numeric,2             Numeric,2
# estimate    0.2727273             0.1818182             0.2
# null.value  0.1238263             0.3280494             0.03912002
# alternative "two.sided"           "two.sided"           "two.sided"
# method      "Exact binomial test" "Exact binomial test" "Exact binomial test"
# data.name   "x and n"             "x and n"             "x and n"

# %%
b_test <- function(x, n, p){  
    binom.test(x, n, p)
    } 

mapply(b_test, summons_matrix[,1:6], summons_matrix[,7], demo_matrix[,1:6])
